# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # 1. Cleaning Dataset : Tourney - Tournament Results

# %%
# Read csv file and put into a dataframe
tourney_df = pd.read_csv("tourney.csv")
tourney_df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  ...  \
# 0    2003     134   1421      92   1411      84    N      1    32    69  ...
# 1    2003     136   1112      80   1436      51    N      0    31    66  ...
# 2    2003     136   1113      84   1272      71    N      0    31    59  ...
# 3    2003     136   1141      79   1166      73    N      0    29    53  ...
# 4    2003     136   1143      76   1301      74    N      1    27    64  ...
#
#    Lfga3  Lftm  Lfta  Lor  Ldr  Last  Lto  Lstl  Lblk  Lpf
# 0     31    14    31   17   28    16   15     5     0   22
# 1     16     7     7    8   26    12   17    10     3   15
# 2     28    14    21   20   22    11   12     2     5   18
# 3     17    12    17   14   17    20   21     6     6   21
# 4     21    15    20   10   26    16   14     5     8   19
#
# [5 rows x 34 columns]

# %%
# Display info
tourney_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 34 columns):
# Season    847 non-null int64
# Daynum    847 non-null int64
# Wteam     847 non-null int64
# Wscore    847 non-null int64
# Lteam     847 non-null int64
# Lscore    847 non-null int64
# Wloc      847 non-null object
# Numot     847 non-null int64
# Wfgm      847 non-null int64
# Wfga      847 non-null int64
# Wfgm3     847 non-null int64
# Wfga3     847 non-null int64
# Wftm      847 non-null int64
# Wfta      847 non-null int64
# Wor       847 non-null int64
# Wdr       847 non-null int64
# Wast      847 non-null int64
# Wto       847 non-null int64
# Wstl      847 non-null int64
# Wblk      847 non-null int64
# Wpf       847 non-null int64
# Lfgm      847 non-null int64
# Lfga      847 non-null int64
# Lfgm3     847 non-null int64
# Lfga3     847 non-null int64
# Lftm      847 non-null int64
# Lfta      847 non-null int64
# Lor       847 non-null int64
# ...

# %%
# Read csv file and put into a dataframe
teams_df = pd.read_csv("teams.csv")
teams_df.head()
# Out:
#    Team_Id    Team_Name
# 0     1101  Abilene Chr
# 1     1102    Air Force
# 2     1103        Akron
# 3     1104      Alabama
# 4     1105  Alabama A&M

# %%
teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 2 columns):
# Team_Id      364 non-null int64
# Team_Name    364 non-null object
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
teams_df['Team_Name'].value_counts()
# Out:
# Wichita St        1
# Montana           1
# North Carolina    1
# Robert Morris     1
# Florida A&M       1
# WI Green Bay      1
# Missouri          1
# Bowling Green     1
# Boston Univ       1
# Wyoming           1
# Fresno St         1
# Canisius          1
# James Madison     1
# Xavier            1
# George Mason      1
# Longwood          1
# S Carolina St     1
# Providence        1
# Arkansas St       1
# Baylor            1
# San Diego         1
# San Francisco     1
# NC Central        1
# Norfolk St        1
# Sacred Heart      1
# Citadel           1
# Miami FL          1
# Syracuse          1
# USC               1
# N Illinois        1
#                  ..
# Stetson           1
# Alabama St        1
# Missouri KC       1
# CS Sacramento     1
# Auburn            1
# Utah Valley       1
# Florida           1
# BYU               1
# Campbell          1
# Drake             1
# Grand Canyon      1
# Illinois          1
# Murray St         1
# Mississippi St    1
# ...

# %%
tourney_df = tourney_df.rename(columns = {'Wteam':'Team_Id'})
tourney_df.head()
# Out:
#    Season  Daynum  Team_Id  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 0    2003     134     1421      92   1411      84    N      1    32    69
# 1    2003     136     1112      80   1436      51    N      0    31    66
# 2    2003     136     1113      84   1272      71    N      0    31    59
# 3    2003     136     1141      79   1166      73    N      0    29    53
# 4    2003     136     1143      76   1301      74    N      1    27    64
#
#    ...  Lfga3  Lftm  Lfta  Lor  Ldr  Last  Lto  Lstl  Lblk  Lpf
# 0  ...     31    14    31   17   28    16   15     5     0   22
# 1  ...     16     7     7    8   26    12   17    10     3   15
# 2  ...     28    14    21   20   22    11   12     2     5   18
# 3  ...     17    12    17   14   17    20   21     6     6   21
# 4  ...     21    15    20   10   26    16   14     5     8   19
#
# [5 rows x 34 columns]

# %%
# Creating new columns for the tournament dataframe based on calculations made using existing columns
# A. Winning Field Goal Percentage
tourney_df['Winning_field_goal_percent'] = (tourney_df['Wfgm']/tourney_df['Wfga']*100).round(2)
tourney_df['Winning_field_goal_percent'].head()
# Out:
# 0    46.38
# 1    46.97
# 2    52.54
# 3    54.72
# 4    42.19
# Name: Winning_field_goal_percent, dtype: float64

# %%
# B. Winning 3 percentage 
tourney_df['Winning_3_percent'] = (tourney_df['Wfgm3']/tourney_df['Wfga3']*100).round(2)
tourney_df['Winning_3_percent'].head()
# Out:
# 0    37.93
# 1    30.43
# 2    42.86
# 3    42.86
# 4    35.00
# Name: Winning_3_percent, dtype: float64

# %%
# C. Winning free throw percentage
tourney_df['Winning_free_throw_percent'] = (tourney_df['Wftm']/tourney_df['Wfta']*100).round(2)
tourney_df['Winning_free_throw_percent'].head()
# Out:
# 0    65.38
# 1    78.57
# 2    72.73
# 3    72.00
# 4    65.22
# Name: Winning_free_throw_percent, dtype: float64

# %%
# D. Winning total rebounds
tourney_df['Winning_total_rebounds'] = (tourney_df['Wor']+tourney_df['Wdr'])
tourney_df['Winning_total_rebounds'].head()
# Out:
# 0    44
# 1    47
# 2    37
# 3    31
# 4    38
# Name: Winning_total_rebounds, dtype: int64

# %%
# E. Losing field goal percentage
tourney_df['Losing_field_goal_percent'] = (tourney_df['Lfgm']/tourney_df['Lfga']*100).round(2)
tourney_df['Losing_field_goal_percent'].head()
# Out:
# 0    43.28
# 1    31.25
# 2    36.23
# 3    45.00
# 4    44.64
# Name: Losing_field_goal_percent, dtype: float64

# %%
# F. Losing 3 Percentage
tourney_df['Losing_3_percent'] = (tourney_df['Lfgm3']/tourney_df['Lfga3']*100).round(2)
tourney_df['Losing_3_percent'].head()
# Out:
# 0    38.71
# 1    25.00
# 2    25.00
# 3    41.18
# 4    42.86
# Name: Losing_3_percent, dtype: float64

# %%
# G. Losing free throw percentage
tourney_df['Losing_free_throw_percent'] = (tourney_df['Lftm']/tourney_df['Lfta']*100).round(2)
tourney_df['Losing_free_throw_percent'].head()
# Out:
# 0     45.16
# 1    100.00
# 2     66.67
# 3     70.59
# 4     75.00
# Name: Losing_free_throw_percent, dtype: float64

# %%
# H. Losing Total Rebounds
tourney_df['Losing_total_rebounds'] = (tourney_df['Lor']+tourney_df['Ldr'])
tourney_df['Losing_total_rebounds'].head()
# Out:
# 0    45
# 1    34
# 2    42
# 3    31
# 4    36
# Name: Losing_total_rebounds, dtype: int64

# %%
# Merge on Team ID to bring over Winning Teams' Names
merged_tourney = pd.merge(tourney_df, teams_df, on = ['Team_Id'])
merged_tourney.head()
# Out:
#    Season  Daynum  Team_Id  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 0    2003     134     1421      92   1411      84    N      1    32    69
# 1    2011     134     1421      81   1114      77    N      1    27    54
# 2    2003     136     1112      80   1436      51    N      0    31    66
# 3    2003     138     1112      96   1211      95    N      2    34    74
# 4    2003     143     1112      88   1323      71    N      0    36    76
#
#    ...  Lpf  Winning_field_goal_percent  Winning_3_percent  \
# 0  ...   22                       46.38              37.93
# 1  ...   24                       50.00              33.33
# 2  ...   15                       46.97              30.43
# 3  ...   25                       45.95              29.17
# 4  ...   16                       47.37              50.00
#
#    Winning_free_throw_percent  Winning_total_rebounds  \
# 0                       65.38                      44
# ...

# %%
# Create a new dataframe by incorporating the calculated columns and indentified columns of interest.
tourney_df2 = merged_tourney[['Season','Team_Name','Wscore',\
                              'Lteam','Lscore','Winning_field_goal_percent',\
                              'Winning_3_percent','Winning_free_throw_percent',\
                              'Winning_total_rebounds','Wast','Wto','Wstl',\
                              'Losing_field_goal_percent','Losing_3_percent',\
                              'Losing_free_throw_percent','Losing_total_rebounds',\
                              'Last','Lto','Lstl']].copy()
tourney_df2.head()
# Out:
#    Season      Team_Name  Wscore  Lteam  Lscore  Winning_field_goal_percent  \
# 0    2003  UNC Asheville      92   1411      84                       46.38
# 1    2011  UNC Asheville      81   1114      77                       50.00
# 2    2003        Arizona      80   1436      51                       46.97
# 3    2003        Arizona      96   1211      95                       45.95
# 4    2003        Arizona      88   1323      71                       47.37
#
#    Winning_3_percent  Winning_free_throw_percent  Winning_total_rebounds  \
# 0              37.93                       65.38                      44
# 1              33.33                       82.14                      35
# 2              30.43                       78.57                      47
# 3              29.17                       72.41                      47
# 4              50.00                       81.82                      44
#
#    Wast  Wto  Wstl  Losing_field_goal_percent  Losing_3_percent  \
# ...

# %%
# Rename columns of interest.
tourney_df2 = tourney_df2.rename(columns={'Season':'season','Team_Name':'winning_team','Wscore':'winning_score','Lteam':'losing_team','Lscore':'losing_score','Wast':'Winning_assists','Wto':'Winning_turnovers','Wstl':'Winning_steals',\
                         'Last':'Losing_assists','Lto':'Losing_turnover','Lstl':'Losing_steals'})
tourney_df2.head()
# Out:
#    season   winning_team  winning_score  losing_team  losing_score  \
# 0    2003  UNC Asheville             92         1411            84
# 1    2011  UNC Asheville             81         1114            77
# 2    2003        Arizona             80         1436            51
# 3    2003        Arizona             96         1211            95
# 4    2003        Arizona             88         1323            71
#
#    Winning_field_goal_percent  Winning_3_percent  Winning_free_throw_percent  \
# 0                       46.38              37.93                       65.38
# 1                       50.00              33.33                       82.14
# 2                       46.97              30.43                       78.57
# 3                       45.95              29.17                       72.41
# 4                       47.37              50.00                       81.82
#
#    Winning_total_rebounds  Winning_assists  Winning_turnovers  Winning_steals  \
# ...

# %%
tourney_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847 entries, 0 to 846
# Data columns (total 19 columns):
# season                        847 non-null int64
# winning_team                  847 non-null object
# winning_score                 847 non-null int64
# losing_team                   847 non-null int64
# losing_score                  847 non-null int64
# Winning_field_goal_percent    847 non-null float64
# Winning_3_percent             847 non-null float64
# Winning_free_throw_percent    847 non-null float64
# Winning_total_rebounds        847 non-null int64
# Winning_assists               847 non-null int64
# Winning_turnovers             847 non-null int64
# Winning_steals                847 non-null int64
# Losing_field_goal_percent     847 non-null float64
# Losing_3_percent              847 non-null float64
# Losing_free_throw_percent     847 non-null float64
# Losing_total_rebounds         847 non-null int64
# Losing_assists                847 non-null int64
# ...

# %%
# Merge tourney_df2 and teams_df to bring over the losing team names using the Team ID column and losing team column.
merged_tourney2 = pd.merge(tourney_df2, teams_df, left_on = 'losing_team', right_on = 'Team_Id')
merged_tourney2.head()
# Out:
#    season   winning_team  winning_score  losing_team  losing_score  \
# 0    2003  UNC Asheville             92         1411            84
# 1    2015        Arizona             93         1411            72
# 2    2014   Cal Poly SLO             81         1411            69
# 3    2011  UNC Asheville             81         1114            77
# 4    2003        Arizona             80         1436            51
#
#    Winning_field_goal_percent  Winning_3_percent  Winning_free_throw_percent  \
# 0                       46.38              37.93                       65.38
# 1                       60.38              45.45                       88.89
# 2                       56.86              40.00                       77.27
# 3                       50.00              33.33                       82.14
# 4                       46.97              30.43                       78.57
#
#    Winning_total_rebounds  Winning_assists  ...  Winning_steals  \
# ...

# %%
# Reposition columns and rename dataframe.
tourney_df3 = merged_tourney2[['season','winning_team','winning_score','Team_Name','losing_score','Winning_field_goal_percent','Winning_3_percent','Winning_free_throw_percent','Winning_total_rebounds','Winning_assists',\
                               'Winning_turnovers','Winning_steals','Losing_field_goal_percent','Losing_3_percent','Losing_free_throw_percent','Losing_total_rebounds','Losing_assists','Losing_turnover','Losing_steals']].copy()
tourney_df3.head()
# Out:
#    season   winning_team  winning_score        Team_Name  losing_score  \
# 0    2003  UNC Asheville             92      TX Southern            84
# 1    2015        Arizona             93      TX Southern            72
# 2    2014   Cal Poly SLO             81      TX Southern            69
# 3    2011  UNC Asheville             81  Ark Little Rock            77
# 4    2003        Arizona             80          Vermont            51
#
#    Winning_field_goal_percent  Winning_3_percent  Winning_free_throw_percent  \
# 0                       46.38              37.93                       65.38
# 1                       60.38              45.45                       88.89
# 2                       56.86              40.00                       77.27
# 3                       50.00              33.33                       82.14
# 4                       46.97              30.43                       78.57
#
# ...

# %%
# Rename the column'Team_Name' to 'losing_team' and sort by season - ascending, winning score - descending, and winning team ascending. Reset the index and drop old index.
tourney_df3 = tourney_df3.rename(columns={'Team_Name':'losing_team'})
sorted = tourney_df3.sort_values(by = ['season','winning_score','winning_team'], ascending = [True,False,True])
#df.sort_values(['a', 'b'], ascending=[True, False])
tourney_df4 = sorted.reset_index(drop=True)
tourney_df4.head()
# Out:
#    season winning_team  winning_score losing_team  losing_score  \
# 0    2003       Kansas            108  Arizona St            76
# 1    2003    Marquette            101    Missouri            92
# 2    2003      Arizona             96     Gonzaga            95
# 3    2003     Kentucky             95       IUPUI            64
# 4    2003     Syracuse             95       Texas            84
#
#    Winning_field_goal_percent  Winning_3_percent  Winning_free_throw_percent  \
# 0                       67.80              55.56                       67.65
# 1                       56.45              66.67                       95.00
# 2                       45.95              29.17                       72.41
# 3                       61.54              50.00                       45.45
# 4                       57.14              53.85                       77.42
#
#    Winning_total_rebounds  Winning_assists  Winning_turnovers  Winning_steals  \
# ...

# %%
# Save new dataframe to a csv file.
tourney_df4.to_csv('tourney_new_clean.csv')

# %% [markdown]
# # 2. Cleaning Dataset - Results - Season Game Results

# %%
# Read csv file and put into a dataframe
results_df = pd.read_csv("results.csv")
results_df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  ...  \
# 0    2003      10   1104      68   1328      62    N      0    27    58  ...
# 1    2003      10   1272      70   1393      63    N      0    26    62  ...
# 2    2003      11   1266      73   1437      61    N      0    24    58  ...
# 3    2003      11   1296      56   1457      50    N      0    18    38  ...
# 4    2003      11   1400      77   1208      71    N      0    30    61  ...
#
#    Lfga3  Lftm  Lfta  Lor  Ldr  Last  Lto  Lstl  Lblk  Lpf
# 0     10    16    22   10   22     8   18     9     2   20
# 1     24     9    20   20   25     7   12     8     6   16
# 2     26    14    23   31   22     9   12     2     5   23
# 3     22     8    15   17   20     9   19     4     3   23
# 4     16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]

# %%
# Display info
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71241 entries, 0 to 71240
# Data columns (total 34 columns):
# Season    71241 non-null int64
# Daynum    71241 non-null int64
# Wteam     71241 non-null int64
# Wscore    71241 non-null int64
# Lteam     71241 non-null int64
# Lscore    71241 non-null int64
# Wloc      71241 non-null object
# Numot     71241 non-null int64
# Wfgm      71241 non-null int64
# Wfga      71241 non-null int64
# Wfgm3     71241 non-null int64
# Wfga3     71241 non-null int64
# Wftm      71241 non-null int64
# Wfta      71241 non-null int64
# Wor       71241 non-null int64
# Wdr       71241 non-null int64
# Wast      71241 non-null int64
# Wto       71241 non-null int64
# Wstl      71241 non-null int64
# Wblk      71241 non-null int64
# Wpf       71241 non-null int64
# Lfgm      71241 non-null int64
# Lfga      71241 non-null int64
# Lfgm3     71241 non-null int64
# Lfga3     71241 non-null int64
# Lftm      71241 non-null int64
# ...

# %%
results_df = results_df.rename(columns = {'Wteam':'Team_Id'})
results_df.head()
# Out:
#    Season  Daynum  Team_Id  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 0    2003      10     1104      68   1328      62    N      0    27    58
# 1    2003      10     1272      70   1393      63    N      0    26    62
# 2    2003      11     1266      73   1437      61    N      0    24    58
# 3    2003      11     1296      56   1457      50    N      0    18    38
# 4    2003      11     1400      77   1208      71    N      0    30    61
#
#    ...  Lfga3  Lftm  Lfta  Lor  Ldr  Last  Lto  Lstl  Lblk  Lpf
# 0  ...     10    16    22   10   22     8   18     9     2   20
# 1  ...     24     9    20   20   25     7   12     8     6   16
# 2  ...     26    14    23   31   22     9   12     2     5   23
# 3  ...     22     8    15   17   20     9   19     4     3   23
# 4  ...     16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]

# %%
# Creating new columns for the tournament dataframe based on calculations made using existing columns
# A. Winning Field Goal Percentage
results_df['Winning_field_goal_percent'] = (results_df['Wfgm']/results_df['Wfga']*100).round(2)
results_df['Winning_field_goal_percent'].head()
# Out:
# 0    46.55
# 1    41.94
# 2    41.38
# 3    47.37
# 4    49.18
# Name: Winning_field_goal_percent, dtype: float64

# %%
# B. Winning 3 percentage 
results_df['Winning_3_percent'] = (results_df['Wfgm3']/results_df['Wfga3']*100).round(2)
results_df['Winning_3_percent'].head()
# Out:
# 0    21.43
# 1    40.00
# 2    44.44
# 3    33.33
# 4    42.86
# Name: Winning_3_percent, dtype: float64

# %%
# C. Winning free throw percentage
results_df['Winning_free_throw_percent'] = (results_df['Wftm']/results_df['Wfta']*100).round(2)
results_df['Winning_free_throw_percent'].head()
# Out:
# 0    61.11
# 1    52.63
# 2    58.62
# 3    54.84
# 4    84.62
# Name: Winning_free_throw_percent, dtype: float64

# %%
# D. Winning total rebounds
results_df['Winning_total_rebounds'] = results_df['Wor']+results_df['Wdr']
results_df['Winning_total_rebounds'].head()
# Out:
# 0    38
# 1    43
# 2    43
# 3    25
# 4    39
# Name: Winning_total_rebounds, dtype: int64

# %%
# E. Losing field goal percentage
results_df['Losing_field_goal_percent'] = (results_df['Lfgm']/results_df['Lfga']*100).round(2)
results_df['Losing_field_goal_percent'].head()
# Out:
# 0    41.51
# 1    35.82
# 2    30.14
# 3    36.73
# 4    38.71
# Name: Losing_field_goal_percent, dtype: float64

# %%
# F. Losing 3 Percentage
results_df['Losing_3_percent'] = (results_df['Lfgm3']/results_df['Lfga3']*100).round(2)
results_df['Losing_3_percent'].head()
# Out:
# 0    20.00
# 1    25.00
# 2    11.54
# 3    27.27
# 4    37.50
# Name: Losing_3_percent, dtype: float64

# %%
# G. Losing free throw percentage
results_df['Losing_free_throw_percent'] = (results_df['Lftm']/results_df['Lfta']*100).round(2)
results_df['Losing_free_throw_percent'].head()
# Out:
# 0    72.73
# 1    45.00
# 2    60.87
# 3    53.33
# 4    62.96
# Name: Losing_free_throw_percent, dtype: float64

# %%
# H. Losing Total Rebounds
results_df['Losing_total_rebounds'] = results_df['Lor']+results_df['Ldr']
results_df['Losing_total_rebounds'].head()
# Out:
# 0    32
# 1    45
# 2    53
# 3    37
# 4    36
# Name: Losing_total_rebounds, dtype: int64

# %%
merged_results = pd.merge(results_df, teams_df, on = ['Team_Id'])
merged_results.head()
# Out:
#    Season  Daynum  Team_Id  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 0    2003      10     1104      68   1328      62    N      0    27    58
# 1    2003      18     1104      82   1106      56    H      0    24    49
# 2    2003      21     1104      80   1292      65    H      0    27    59
# 3    2003      25     1104      54   1326      48    N      0    16    57
# 4    2003      29     1104      89   1422      61    H      0    34    70
#
#    ...  Lpf  Winning_field_goal_percent  Winning_3_percent  \
# 0  ...   20                       46.55              21.43
# 1  ...   22                       48.98              50.00
# 2  ...   20                       45.76              33.33
# 3  ...   19                       28.07              28.00
# 4  ...   15                       48.57              40.91
#
#    Winning_free_throw_percent  Winning_total_rebounds  \
# 0                       61.11                      38
# ...

# %%
# Create a new dataframe by incorporating the calculated columns and indentified columns of interest.
results_df2 = merged_results[['Season','Team_Name','Wscore',\
          'Lteam','Lscore','Winning_field_goal_percent','Winning_3_percent','Winning_free_throw_percent'\
          ,'Winning_total_rebounds','Wast','Wto','Wstl','Losing_field_goal_percent','Losing_3_percent','Losing_free_throw_percent'\
         ,'Losing_total_rebounds','Last','Lto','Lstl']].copy()
tourney_df2
# Out:
#      season   winning_team  winning_score  losing_team  losing_score  \
# 0      2003  UNC Asheville             92         1411            84
# 1      2011  UNC Asheville             81         1114            77
# 2      2003        Arizona             80         1436            51
# 3      2003        Arizona             96         1211            95
# 4      2003        Arizona             88         1323            71
# 5      2005        Arizona             66         1429            53
# 6      2005        Arizona             85         1412            63
# 7      2005        Arizona             79         1329            78
# 8      2006        Arizona             94         1458            75
# 9      2009        Arizona             84         1428            71
# 10     2009        Arizona             71         1156            57
# 11     2011        Arizona             77         1272            75
# 12     2011        Arizona             70         1400            69
# ...

# %%
# Rename identified columns of interest.
results_df2 = results_df2.rename(columns={'Season':'season','Team_Name':'winning_team','Wscore':'winning_score','Lteam':'losing_team','Lscore':'losing_score','Wast':'Winning_assists','Wto':'Winning_turnovers','Wstl':'Winning_steals',\
                         'Last':'Losing_assists','Lto':'Losing_turnover','Lstl':'Losing_steals'})
results_df2.head()
# Out:
#    season winning_team  winning_score  losing_team  losing_score  \
# 0    2003      Alabama             68         1328            62
# 1    2003      Alabama             82         1106            56
# 2    2003      Alabama             80         1292            65
# 3    2003      Alabama             54         1326            48
# 4    2003      Alabama             89         1422            61
#
#    Winning_field_goal_percent  Winning_3_percent  Winning_free_throw_percent  \
# 0                       46.55              21.43                       61.11
# 1                       48.98              50.00                       70.59
# 2                       45.76              33.33                       78.26
# 3                       28.07              28.00                       71.43
# 4                       48.57              40.91                       80.00
#
#    Winning_total_rebounds  Winning_assists  Winning_turnovers  Winning_steals  \
# ...

# %%
results_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71241 entries, 0 to 71240
# Data columns (total 19 columns):
# season                        71241 non-null int64
# winning_team                  71241 non-null object
# winning_score                 71241 non-null int64
# losing_team                   71241 non-null int64
# losing_score                  71241 non-null int64
# Winning_field_goal_percent    71241 non-null float64
# Winning_3_percent             71241 non-null float64
# Winning_free_throw_percent    71237 non-null float64
# Winning_total_rebounds        71241 non-null int64
# Winning_assists               71241 non-null int64
# Winning_turnovers             71241 non-null int64
# Winning_steals                71241 non-null int64
# Losing_field_goal_percent     71241 non-null float64
# Losing_3_percent              71241 non-null float64
# Losing_free_throw_percent     71216 non-null float64
# Losing_total_rebounds         71241 non-null int64
# ...

# %%
# Merge tourney_df2 and teams_df to bring over the losing team names using the Team ID column and losing team column.
merged_results2 = pd.merge(results_df2, teams_df, left_on = 'losing_team', right_on = 'Team_Id')
merged_results2.head()
# Out:
#    season winning_team  winning_score  losing_team  losing_score  \
# 0    2003      Alabama             68         1328            62
# 1    2007      Alabama             70         1328            55
# 2    2007      Memphis             77         1328            65
# 3    2008      Memphis             63         1328            53
# 4    2003        Texas             67         1328            61
#
#    Winning_field_goal_percent  Winning_3_percent  Winning_free_throw_percent  \
# 0                       46.55              21.43                       61.11
# 1                       45.83              36.36                       91.67
# 2                       49.02              41.18                       54.05
# 3                       38.60              32.00                       47.83
# 4                       39.06              35.71                       60.00
#
#    Winning_total_rebounds  Winning_assists  ...  Winning_steals  \
# ...

# %%
# Reposition columns and rename dataframe.
results_df3 = merged_results2[['season','winning_team','winning_score','Team_Name','losing_score','Winning_field_goal_percent','Winning_3_percent','Winning_free_throw_percent','Winning_total_rebounds','Winning_assists',\
                               'Winning_turnovers','Winning_steals','Losing_field_goal_percent','Losing_3_percent','Losing_free_throw_percent','Losing_total_rebounds','Losing_assists','Losing_turnover','Losing_steals']].copy()
results_df3.head()
# Out:
#    season winning_team  winning_score Team_Name  losing_score  \
# 0    2003      Alabama             68  Oklahoma            62
# 1    2007      Alabama             70  Oklahoma            55
# 2    2007      Memphis             77  Oklahoma            65
# 3    2008      Memphis             63  Oklahoma            53
# 4    2003        Texas             67  Oklahoma            61
#
#    Winning_field_goal_percent  Winning_3_percent  Winning_free_throw_percent  \
# 0                       46.55              21.43                       61.11
# 1                       45.83              36.36                       91.67
# 2                       49.02              41.18                       54.05
# 3                       38.60              32.00                       47.83
# 4                       39.06              35.71                       60.00
#
#    Winning_total_rebounds  Winning_assists  Winning_turnovers  Winning_steals  \
# ...

# %%
# Rename the column'Team_Name' to 'losing_team' and sort by season - ascending, winning score - descending, and winning team ascending. 
# Reset the index and drop old index.
results_df3 = results_df3.rename(columns={'Team_Name':'losing_team'})
sorted_results = results_df3.sort_values(by = ['season','winning_score','winning_team'], ascending = [True,False,True])
#df.sort_values(['a', 'b'], ascending=[True, False])
results_df4 = sorted_results.reset_index(drop=True)
results_df4
# Out:
#        season     winning_team  winning_score      losing_team  losing_score  \
# 0        2003    St Francis NY            142      Long Island           140
# 1        2003      Connecticut            117    UNC Asheville            67
# 2        2003             Troy            117          Stetson            70
# 3        2003      Connecticut            116     Sacred Heart            78
# 4        2003       Pepperdine            116  Ark Little Rock           110
# 5        2003         Kentucky            115     Tennessee St            87
# 6        2003     Georgia Tech            113   Ark Pine Bluff            75
# 7        2003              LSU            112        Centenary            65
# 8        2003             Ohio            112            Akron           104
# 9        2003          Wyoming            112      Savannah St            77
# 10       2003          Gonzaga            110    Washington St           104
# ...

# %%
# Save new dataframe to a csv file.
tourney_df4.to_csv('tourney_new_clean.csv')

# %%
results_df4.to_csv('results_new_clean.csv')

# %%
connection_string = "postgres:@localhost:5432/marchmadness_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
tourney_df4.to_sql(name='tourney', con=engine, if_exists='append', index=True)

# %%
results_df4.to_sql(name='results', con=engine, if_exists='append', index=True)

# %%
teams_df.to_sql(name='teams', con=engine, if_exists='append', index=True)

# %%
engine.table_names()
# Out:
# ['teams', 'tourney', 'results']

# %%
conn = engine.connect()

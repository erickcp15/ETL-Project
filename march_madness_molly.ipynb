# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
teams_file = "Teams.csv"
teams_df = pd.read_csv(teams_file)
teams_df.head()
# Out:
#    Team_Id    Team_Name
# 0     1101  Abilene Chr
# 1     1102    Air Force
# 2     1103        Akron
# 3     1104      Alabama
# 4     1105  Alabama A&M

# %%
teams_df = teams_df.rename(columns={"Team_ID": "id",
                                    "Team_Name": "Team"})
teams_df.head()
# Out:
#    Team_Id         Team
# 0     1101  Abilene Chr
# 1     1102    Air Force
# 2     1103        Akron
# 3     1104      Alabama
# 4     1105  Alabama A&M

# %%
results_file = "results.csv"
results_df = pd.read_csv(results_file)
results_df.head()
# Out:
#    Wteam_name Lteam_name  Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  \
# 0     Alabama   Oklahoma    2003      10   1104      68   1328      62    N
# 1     Memphis   Syracuse    2003      10   1272      70   1393      63    N
# 2   Marquette  Villanova    2003      11   1266      73   1437      61    N
# 3  N Illinois   Winthrop    2003      11   1296      56   1457      50    N
# 4       Texas    Georgia    2003      11   1400      77   1208      71    N
#
#    Numot  ...  Lfga3  Lftm  Lfta  Lor  Ldr  Last  Lto  Lstl  Lblk  Lpf
# 0      0  ...     10    16    22   10   22     8   18     9     2   20
# 1      0  ...     24     9    20   20   25     7   12     8     6   16
# 2      0  ...     26    14    23   31   22     9   12     2     5   23
# 3      0  ...     22     8    15   17   20     9   19     4     3   23
# 4      0  ...     16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 36 columns]

# %%
tourney_file = "tourney.csv"
tourney_df = pd.read_csv(tourney_file)
tourney_df.columns
# Out:
# Index(['Wteam_name', 'Lteam_name', 'Season', 'Daynum', 'Wteam', 'Wscore',
#        'Lteam', 'Lscore', 'Wloc', 'Numot', 'Wfgm', 'Wfga', 'Wfgm3', 'Wfga3',
#        'Wftm', 'Wfta', 'Wor', 'Wdr', 'Wast', 'Wto', 'Wstl', 'Wblk', 'Wpf',
#        'Lfgm', 'Lfga', 'Lfgm3', 'Lfga3', 'Lftm', 'Lfta', 'Lor', 'Ldr', 'Last',
#        'Lto', 'Lstl', 'Lblk', 'Lpf'],
#       dtype='object')

# %%
results_columns= results_df[['Wteam_name', 'Lteam_name', 'Season', 'Wscore', 'Lscore', 'Wfgm', 'Wfga', 'Wfgm3', 'Wfga3',
       'Wftm', 'Wfta', 'Wor', 'Wdr', 'Wast', 'Wto', 'Wstl', 'Lfgm', 'Lfga', 'Lfgm3', 'Lfga3', 'Lftm', 'Lfta', 'Lor', 'Ldr', 'Last',
       'Lto', 'Lstl']].copy()

results_clean = results_columns.rename(columns={"Wteam_name": "winning_team",
                                                "Lteam_name": "losing_team",
                                                "Season": "season",
                                               "Wscore": "winning_score",
                                               "Lscore": "losing_score"
                                               })

results_clean.head()
# Out:
#   winning_team losing_team  season  winning_score  losing_score  Wfgm  Wfga  \
# 0      Alabama    Oklahoma    2003             68            62    27    58
# 1      Memphis    Syracuse    2003             70            63    26    62
# 2    Marquette   Villanova    2003             73            61    24    58
# 3   N Illinois    Winthrop    2003             56            50    18    38
# 4        Texas     Georgia    2003             77            71    30    61
#
#    Wfgm3  Wfga3  Wftm  ...  Lfga  Lfgm3  Lfga3  Lftm  Lfta  Lor  Ldr  Last  \
# 0      3     14    11  ...    53      2     10    16    22   10   22     8
# 1      8     20    10  ...    67      6     24     9    20   20   25     7
# 2      8     18    17  ...    73      3     26    14    23   31   22     9
# 3      3      9    17  ...    49      6     22     8    15   17   20     9
# 4      6     14    11  ...    62      6     16    17    27   21   15    12
#
#    Lto  Lstl
# 0   18     9
# 1   12     8
# 2   12     2
# ...

# %%
results_clean.to_csv('results_clean.csv')

# %%
tourney_columns= tourney_df[['Wteam_name', 'Lteam_name', 'Season', 'Wscore',
       'Lteam', 'Wfgm', 'Wfga', 'Wfgm3', 'Wfga3',
       'Wftm', 'Wfta', 'Wor', 'Wdr', 'Wast', 'Wto', 'Wstl', 'Lfgm', 'Lfga', 'Lfgm3', 'Lfga3', 'Lftm', 'Lfta', 'Lor', 'Ldr', 'Last',
       'Lto', 'Lstl']].copy()

tourney_clean = tourney_columns.rename(columns={"Wteam_name": "winning_team",
                                                "Lteam_name": "losing_team",
                                                "Season": "season",
                                               "Wscore": "winning_score",
                                               "Lscore": "losing_score"})

tourney_clean.head()
# Out:
#     winning_team  losing_team  season  winning_score  Lteam  Wfgm  Wfga  \
# 0  UNC Asheville  TX Southern    2003             92   1411    32    69
# 1        Arizona      Vermont    2003             80   1436    31    66
# 2     Arizona St      Memphis    2003             84   1272    31    59
# 3     C Michigan    Creighton    2003             79   1166    29    53
# 4     California     NC State    2003             76   1301    27    64
#
#    Wfgm3  Wfga3  Wftm  ...  Lfga  Lfgm3  Lfga3  Lftm  Lfta  Lor  Ldr  Last  \
# 0     11     29    17  ...    67     12     31    14    31   17   28    16
# 1      7     23    11  ...    64      4     16     7     7    8   26    12
# 2      6     14    16  ...    69      7     28    14    21   20   22    11
# 3      3      7    18  ...    60      7     17    12    17   14   17    20
# 4      7     20    15  ...    56      9     21    15    20   10   26    16
#
#    Lto  Lstl
# 0   15     5
# 1   17    10
# 2   12     2
# 3   21     6
# ...

# %%
tourney_clean.to_csv('tourney_clean.csv')

# %%
results_new_clean = "results_new_clean.csv"
results_df = pd.read_csv(results_new_clean)
results_df.head()
# Out:
#    season   winning_team  winning_score      losing_team  losing_score  \
# 0    2003  St Francis NY            142      Long Island           140
# 1    2003    Connecticut            117    UNC Asheville            67
# 2    2003           Troy            117          Stetson            70
# 3    2003    Connecticut            116     Sacred Heart            78
# 4    2003     Pepperdine            116  Ark Little Rock           110
#
#    Winning_field_goal_percent  Winning_3_percent  Winning_free_throw_percent  \
# 0                       54.65              36.67                       80.43
# 1                       62.67              45.45                       68.42
# 2                       57.53              44.12                       72.00
# 3                       50.00              26.09                       76.47
# 4                       48.81              40.62                       63.64
#
# ...

# %%
tourney_new_clean = "tourney_new_clean.csv"
tourney_df = pd.read_csv(tourney_new_clean)
tourney_df.head()
# Out:
#    season winning_team  winning_score losing_team  losing_score  \
# 0    2003       Kansas            108  Arizona St            76
# 1    2003    Marquette            101    Missouri            92
# 2    2003      Arizona             96     Gonzaga            95
# 3    2003     Kentucky             95       IUPUI            64
# 4    2003     Syracuse             95       Texas            84
#
#    Winning_field_goal_percent  Winning_3_percent  Winning_free_throw_percent  \
# 0                       67.80              55.56                       67.65
# 1                       56.45              66.67                       95.00
# 2                       45.95              29.17                       72.41
# 3                       61.54              50.00                       45.45
# 4                       57.14              53.85                       77.42
#
#    Winning_total_rebounds  Winning_assists  Winning_turnovers  Winning_steals  \
# ...

# %%
connection_string = "postgres:Mrtubbs10@localhost:5432/march_madness2.0"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['teams']

# %%
teams_df.to_sql(name='teams', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cb9451b71f7a> in <module>
# ----> 1 teams_df.to_sql(name='teams', con=engine, if_exists='append', index=True)
#
# NameError: name 'teams_df' is not defined

# %%
results_df.to_sql(name='results', con=engine, if_exists='append', index=True)

# %%
tourney_df.to_sql(name='tourney', con=engine, if_exists='append', index=True)

# %%
conn = engine.connect()

duke_2015_data = pd.read_sql("select * from results\
                    where season='2015' \
                    and winning_team='Duke'\
                    union\
                    select * from results\
                    where season='2015'\
                    and losing_team='Duke'\
                    union\
                    select * from tourney\
                    where season='2015'\
                    and winning_team='Duke'\
                    order by index asc", conn)
duke_2015_data
# Out:
#     index  season winning_team  winning_score     losing_team  losing_score  \
# 0     788    2015         Duke             85   Robert Morris            56
# 1     792    2015         Duke             81     Michigan St            61
# 2     823    2015         Duke             68       Wisconsin            63
# 3     824    2015         Duke             68    San Diego St            49
# 4     831    2015         Duke             66         Gonzaga            52
# 5     836    2015         Duke             63            Utah            57
# 6   60521    2015         Duke            113    Presbyterian            44
# 7   60529    2015         Duke            109       Fairfield            59
# 8   60658    2015         Duke             94     Wake Forest            51
# 9   60685    2015         Duke             93          Furman            54
# 10  60686    2015         Duke             93            Army            73
# ...

# %%
wisconsin_2015_data = pd.read_sql("select * from results\
                    where season='2015' \
                    and winning_team='Wisconsin'\
                    union\
                    select * from results\
                    where season='2015'\
                    and losing_team='Wisconsin'\
                    union\
                    select * from tourney\
                    where season='2015'\
                    and winning_team='Wisconsin'\
                    union\
                    select * from tourney\
                    where season='2015'\
                    and losing_team='Wisconsin'\
                    order by index asc", conn)
wisconsin_2015_data
# Out:
#     index  season winning_team  winning_score     losing_team  losing_score  \
# 0     787    2015    Wisconsin             86     Coastal Car            72
# 1     789    2015    Wisconsin             85         Arizona            78
# 2     799    2015    Wisconsin             79  North Carolina            72
# 3     814    2015    Wisconsin             72          Oregon            65
# 4     817    2015    Wisconsin             71        Kentucky            64
# 5     823    2015         Duke             68       Wisconsin            63
# 6   60712    2015    Wisconsin             93    WI Milwaukee            54
# 7   60749    2015    Wisconsin             92         Indiana            78
# 8   60901    2015    Wisconsin             89     Chattanooga            45
# 9   60902    2015    Wisconsin             89         Penn St            72
# 10  61112    2015    Wisconsin             86     Nicholls St            43
# ...

# %%
duke_2015_data.to_csv("duke_2015_data.csv")
wisconsin_2015_data.to_csv("wisconsin_2015_data.csv")
